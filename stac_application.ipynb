# %%
# import libraries and functions here
import numpy as np
import geopandas as gpd
import rioxarray as rioxr
import matplotlib.pyplot as plt

from shapely.geometry import Polygon

# used to access STAC catalogs
from pystac_client import Client
# used to sign items from the MPC STAC catalog
import planetary_computer

# ----- other libraries for nice ouputs
from IPython.display import Image

# %% [markdown]
# ## Access
#
# We use the `Client` function from the `pystac_client` package to access the catalog:

# %%
#access catalog 

catalog = Client.open('https://planetarycomputer.microsoft.com/api/stac/v1',
                     modifier = planetary_computer.sign_inplace)

# %% [markdown]
# the `modifier` parameter is needed to acces the data in the MPC catalog
#
# ### Exploration
#
# Lets check out some of the catalogs metadata:

# %%
#metadata from the catalog 

print('Title', catalog.title)

print('Description', catalog.description)
# Out:
# Title Microsoft Planetary Computer STAC API
# Description Searchable spatiotemporal metadata describing Earth science datasets hosted by the Microsoft Planetary Computer

# %% [markdown]
# We can use the catalog's collections by using the `get_collections()` method:

# %%
catalog.get_collections()
# Out:
# <generator object Client.get_collections at 0x189f0dcf0>

# %% [markdown]
# Notice the output of the `get_collections()` is a **generator**.
#
# This is a special kind of *lazy* object in the python over which you can loop over like alist. Unlike a list, the items ont he generator do not exist in the memory until you explecitly interate over them or convert them to a `list`.

# %%
# get collections and print their names
collections = list(catalog.get_collections())

print('Number of collections:', len(collections))
print("Collections IDs:")
for collection in collections:
    print('-', collection.id)
# Out:
# Number of collections: 122
# Collections IDs:
# - daymet-annual-pr
# - daymet-daily-hi
# - 3dep-seamless
# - 3dep-lidar-dsm
# - fia
# - sentinel-1-rtc
# - gridmet
# - daymet-annual-na
# - daymet-monthly-na
# - daymet-annual-hi
# - daymet-monthly-hi
# - daymet-monthly-pr
# - gnatsgo-tables
# - hgb
# - cop-dem-glo-30
# - cop-dem-glo-90
# - goes-cmi
# - terraclimate
# - nasa-nex-gddp-cmip6
# - gpm-imerg-hhr
# - gnatsgo-rasters
# - 3dep-lidar-hag
# - 3dep-lidar-intensity
# - 3dep-lidar-pointsourceid
# - mtbs
# - noaa-c-cap
# - 3dep-lidar-copc
# - modis-64A1-061
# - alos-fnf-mosaic
# - 3dep-lidar-returns
# - mobi
# - landsat-c2-l2
# - era5-pds
# - chloris-biomass
# - kaza-hydroforecast
# - planet-nicfi-analytic
# - modis-17A2H-061
# - modis-11A2-061
# - daymet-daily-pr
# - 3dep-lidar-dtm-native
# - 3dep-lidar-classification
# - 3dep-lidar-dtm
# - gap
# - modis-17A2HGF-061
# - planet-nicfi-visual
# - gbif
# - modis-17A3HGF-061
# - modis-09A1-061
# - alos-dem
# - alos-palsar-mosaic
# - deltares-water-availability
# - modis-16A3GF-061
# - modis-21A2-061
# - us-census
# - jrc-gsw
# - deltares-floods
# - modis-43A4-061
# - modis-09Q1-061
# - modis-14A1-061
# - hrea
# - modis-13Q1-061
# - modis-14A2-061
# - sentinel-2-l2a
# - modis-15A2H-061
# - modis-11A1-061
# - modis-15A3H-061
# - modis-13A1-061
# - daymet-daily-na
# - nrcan-landcover
# - modis-10A2-061
# - ecmwf-forecast
# - noaa-mrms-qpe-24h-pass2
# - sentinel-1-grd
# - nasadem
# - io-lulc
# - landsat-c2-l1
# - drcog-lulc
# - chesapeake-lc-7
# - chesapeake-lc-13
# - chesapeake-lu
# - noaa-mrms-qpe-1h-pass1
# - noaa-mrms-qpe-1h-pass2
# - noaa-nclimgrid-monthly
# - goes-glm
# - usda-cdl
# - eclipse
# - esa-cci-lc
# - esa-cci-lc-netcdf
# - fws-nwi
# - usgs-lcmap-conus-v13
# - usgs-lcmap-hawaii-v10
# - noaa-climate-normals-tabular
# - noaa-climate-normals-netcdf
# - noaa-climate-normals-gridded
# - aster-l1t
# - cil-gdpcir-cc-by-sa
# - io-lulc-9-class
# - io-biodiversity
# - naip
# - noaa-cdr-sea-surface-temperature-whoi
# - noaa-cdr-ocean-heat-content
# - cil-gdpcir-cc0
# - cil-gdpcir-cc-by
# - noaa-cdr-sea-surface-temperature-whoi-netcdf
# - noaa-cdr-sea-surface-temperature-optimum-interpolation
# - modis-10A1-061
# - sentinel-5p-l2-netcdf
# - sentinel-3-olci-wfr-l2-netcdf
# - noaa-cdr-ocean-heat-content-netcdf
# - sentinel-3-synergy-aod-l2-netcdf
# - sentinel-3-synergy-v10-l2-netcdf
# - sentinel-3-olci-lfr-l2-netcdf
# - sentinel-3-sral-lan-l2-netcdf
# - sentinel-3-slstr-lst-l2-netcdf
# - sentinel-3-slstr-wst-l2-netcdf
# - sentinel-3-sral-wat-l2-netcdf
# - ms-buildings
# - sentinel-3-slstr-frp-l2-netcdf
# - sentinel-3-synergy-syn-l2-netcdf
# - sentinel-3-synergy-vgp-l2-netcdf
# - sentinel-3-synergy-vg1-l2-netcdf
# - esa-worldcover

# %% [markdown]
# ## Collection
#
# We can select a single collection for exploration using the get_child() method for the catalog and the collection id as the parameter:

# %%
naip_collection = catalog.get_child('naip')
naip_collection
# Out:
# <CollectionClient id=naip>

# %% [markdown]
# ## Catalog search
#
# We can narrow the search withing the `catalog` by specifying a time range, an area of interest, and the collection name. The simplest ways to define the area of interest to look for data in the catalog are:
#
# a GeoJSON-type dictionary with the coordinates of the bounding box,
# as a list `[xmin, ymin, xmax, ymax]` with the coordinate values defining the four corners of the bounding box.
# In this lesson we will look for the NAIP scenes over Santa Barbara from 2018 to 2023. We’ll use the GeoJSON method to define the area of interest:
#
# In this lesson we will look for the NAIP scenes over Santa Barbara from 2018 to 2023. We’ll use the GeoJSON method to define the area of interest:

# %%
# Temporal range of interest
time_range = "2018-01-01/2023-01-01"

# NCEAS bounding box (as a GeoJSON)
bbox = {
    "type": "Polygon",
    "coordinates":[
        [
            [-119.70608227128903, 34.426300194372274],
            [-119.70608227128903, 34.42041139020533],
            [-119.6967885126002, 34.42041139020533],
            [-119.6967885126002, 34.426300194372274],
            [-119.70608227128903, 34.426300194372274]
        ]
    ],
}

# catalog search
search = catalog.search(
    collections=['naip'],
    intersects=bbox,
    datetime=time_range)
search

# %% [markdown]
# To get the items found in the search (or check if there were any matches in the search) we use the `item_collection()` method:

# %%
items = search.item_collection()
len(items)
# Out:
# 2

# %% [markdown]
# This output tells us there were two items in the catalog that matched our search!

# %%
items
# Out:
# <style>
# .pystac-summary {
#     cursor: pointer;
#     display:list-item;
# }
# .pystac-key {
#     color: rgb(0, 128, 0);
#     font-weight: 700;
# }
# .pystac-key-value {
#     display: inline-block;
#     margin: 0px 0.5em 0px 0px;
# }
# </style>
# <div class="jp-RenderedJSON jp-mod-trusted jp-OutputArea-output">
#     <div class="container" style="line-height: normal;">
#         <ul style="padding: 0px; margin: 0px; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">type</span>
#             <span style="color: rgb(186, 33, 33);">"FeatureCollection"</span>
#         </li>
#
#
#
#
#                     <li><details>
#         <summary class="pystac-summary">
#             <span class="pystac-key">features</span>
#             <span style="padding-left: 0.5em; color: rgb(64, 128, 128); font-style: italic;">[] 2 items</span>
#         </summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-key">0</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">type</span>
#             <span style="color: rgb(186, 33, 33);">"Feature"</span>
#         </li>
#
#
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">stac_version</span>
#             <span style="color: rgb(186, 33, 33);">"1.0.0"</span>
#         </li>
#
#
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">id</span>
#             <span style="color: rgb(186, 33, 33);">"ca_m_3411935_sw_11_060_20200521"</span>
#         </li>
#
#
#
#
#
#         <li><details>
#             <summary class="pystac-summary"><span class="pystac-key">properties</span></summary>
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">gsd</span>
#             <span style="color: rgb(186, 33, 33);">0.6</span>
#         </li>
#
#
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">datetime</span>
#             <span style="color: rgb(186, 33, 33);">"2020-05-21T00:00:00Z"</span>
#         </li>
#
#
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">naip:year</span>
#             <span style="color: rgb(186, 33, 33);">"2020"</span>
#         </li>
#
#
#
#
#                 <li><details>
#         <summary class="pystac-summary">
#             <span class="pystac-key">proj:bbox</span>
#             <span style="padding-left: 0.5em; color: rgb(64, 128, 128); font-style: italic;">[] 4 items</span>
#         </summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">0</span>
#             <span style="color: rgb(186, 33, 33);">246930.0</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">1</span>
#             <span style="color: rgb(186, 33, 33);">3806808.0</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">2</span>
#             <span style="color: rgb(186, 33, 33);">253260.0</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">3</span>
#             <span style="color: rgb(186, 33, 33);">3814296.0</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">proj:epsg</span>
#             <span style="color: rgb(186, 33, 33);">26911</span>
#         </li>
#
#
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">naip:state</span>
#             <span style="color: rgb(186, 33, 33);">"ca"</span>
#         </li>
#
#
#
#
#                 <li><details>
#         <summary class="pystac-summary">
#             <span class="pystac-key">proj:shape</span>
#             <span style="padding-left: 0.5em; color: rgb(64, 128, 128); font-style: italic;">[] 2 items</span>
#         </summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">0</span>
#             <span style="color: rgb(186, 33, 33);">12480</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">1</span>
#             <span style="color: rgb(186, 33, 33);">10550</span>
#         </li>
#
#
#
#     </ul>
#
#     </details></li>
#
#
#
#                 <li><details>
#         <summary class="pystac-summary">
#             <span class="pystac-key">proj:transform</span>
#             <span style="padding-left: 0.5em; color: rgb(64, 128, 128); font-style: italic;">[] 9 items</span>
#         </summary>
#
#             <ul style="margin: 0px; padding: 0px 0px 0px 1.75em; list-style: none; display: block;">
#
#
#
#         <li style="overflow-wrap: break-word; padding-left: 2.125em; text-indent: -0.5em;">
#             <span class="pystac-key pystac-key-value">0</span>
#             <span style="color: rgb(186, 33, 33);">0.6</span>
#         </li>
#
#
#
#     </ul>
#
#             <ul style="margin: 0px; padding:

# %% [markdown]
# ## Item
#
# Let’s get the first item in the search:

# %%
# get first item in the catalog search
item = items[0]
type(item)
# Out:
# pystac.item.Item

# %% [markdown]
# Remember the STAC item is the core object in the catalog and. The item does not contain the data itself, but rather metadata about and links to access the actual data (assets). Some of the metadata:

# %%
# print item id and properties
print('id:' , item.id)
item.properties
# Out:
# id: ca_m_3411935_sw_11_060_20200521
# {'gsd': 0.6,
#  'datetime': '2020-05-21T00:00:00Z',
#  'naip:year': '2020',
#  'proj:bbox': [246930.0, 3806808.0, 253260.0, 3814296.0],
#  'proj:epsg': 26911,
#  'naip:state': 'ca',
#  'proj:shape': [12480, 10550],
#  'proj:transform': [0.6, 0.0, 246930.0, 0.0, -0.6, 3814296.0, 0.0, 0.0, 1.0]}

# %% [markdown]
# Just as the item properties, the item assets are given in a dictionary, with each value being an `pystac.asset` Let’s check the assets in the `item`:

# %%
item.assets
# Out:
# {'image': <Asset href=https://naipeuwest.blob.core.windows.net/naip/v002/ca/2020/ca_060cm_2020/34119/m_3411935_sw_11_060_20200521.tif?st=2023-11-28T21%3A44%3A45Z&se=2023-11-29T22%3A29%3A45Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-11-29T13%3A45%3A44Z&ske=2023-12-06T13%3A45%3A44Z&sks=b&skv=2021-06-08&sig=2/tUg1wjHdrO0SJMZZRLeoJzp6I4kGY6ju/o5TD4VhA%3D>,
#  'thumbnail': <Asset href=https://naipeuwest.blob.core.windows.net/naip/v002/ca/2020/ca_060cm_2020/34119/m_3411935_sw_11_060_20200521.200.jpg?st=2023-11-28T21%3A44%3A45Z&se=2023-11-29T22%3A29%3A45Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-11-29T13%3A45%3A44Z&ske=2023-12-06T13%3A45%3A44Z&sks=b&skv=2021-06-08&sig=2/tUg1wjHdrO0SJMZZRLeoJzp6I4kGY6ju/o5TD4VhA%3D>,
#  'tilejson': <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=naip&item=ca_m_3411935_sw_11_060_20200521&assets=image&asset_bidx=image%7C1%2C2%2C3&format=png>,
#  'rendered_preview': <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=naip&item=ca_m_3411935_sw_11_060_20200521&assets=image&asset_bidx=image%7C1%2C2%2C3&format=png>}

# %%
for key in item.assets.keys():
    print(key, '--', item.assets[key].title)
# Out:
# image -- RGBIR COG tile
# thumbnail -- Thumbnail
# tilejson -- TileJSON with default rendering
# rendered_preview -- Rendered preview

# %% [markdown]
# Notice each asset has an href, which is a link to the asset object (i.e. the data). For example, we can use the URL for the rendered preview asset to plot it:

# %%
# plot rendered preview
Image(url=item.assets['rendered_preview'].href, width=500)
# Out:
# <img src="https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=naip&item=ca_m_3411935_sw_11_060_20200521&assets=image&asset_bidx=image%7C1%2C2%2C3&format=png" width="500"/>

# %% [markdown]
# ## Load Data
#
# The raster data in our current item is in the image asset. Again, we access this data via its URL. This time, we open it using rioxr.open_rasterio() directly:

# %%
sb = rioxr.open_rasterio(item.assets['image'].href)
sb
# Out:
# <xarray.DataArray (band: 4, y: 12480, x: 10550)>
# [526656000 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1 2 3 4
#   * x            (x) float64 2.469e+05 2.469e+05 ... 2.533e+05 2.533e+05
#   * y            (y) float64 3.814e+06 3.814e+06 ... 3.807e+06 3.807e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:             Area
#     TIFFTAG_IMAGEDESCRIPTION:  OrthoVista
#     TIFFTAG_RESOLUTIONUNIT:    1 (unitless)
#     TIFFTAG_SOFTWARE:          Trimble Germany GmbH
#     TIFFTAG_XRESOLUTION:       1
#     TIFFTAG_YRESOLUTION:       1
#     _FillValue:                0
#     scale_factor:              1.0
#     add_offset:                0.0

# %% [markdown]
# Notice this raster has four bands. So we cannot use the `.plot.imshow()` method directly (as this function only works when we have three bands). Thus we need select the bands we want to plot (RGB) before plotting:

# %%
# plot raster with correct ratio
size = 6 # height in in of plot height
aspect = sb.rio.width / sb.rio.height 
# select R,G,B bands and plot
sb.sel(band=[1,2,3]).plot.imshow(size=size, aspect=aspect)
# Out:
# ERROR 1: TIFFFillTile:Read error at row 3072, col 10240, tile 196; got 0 bytes, expected 777275
# ERROR 1: TIFFReadEncodedTile() failed.
# ERROR 1: IReadBlock failed at X offset 7, Y offset 9: TIFFReadEncodedTile() failed.
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File rasterio/_io.pyx:975, in rasterio._io.DatasetReaderBase._read()
#
# File rasterio/_io.pyx:213, in rasterio._io.io_multi_band()
#
# File rasterio/_err.pyx:195, in rasterio._err.exc_wrap_int()
#
# CPLE_AppDefinedError: IReadBlock failed at X offset 7, Y offset 9: TIFFReadEncodedTile() failed.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[16], line 5
#       3 aspect = sb.rio.width / sb.rio.height
#       4 # select R,G,B bands and plot
# ----> 5 sb.sel(band=[1,2,3]).plot.imshow(size=size, aspect=aspect)
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/plot/accessor.py:433, in DataArrayPlotAccessor.imshow(self, *args, **kwargs)
#     431 @functools.wraps(dataarray_plot.imshow, assigned=("__doc__",))
#     432 def imshow(self, *args, **kwargs) -> AxesImage | FacetGrid[DataArray]:
# --> 433     return dataarray_plot.imshow(self._da, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/plot/dataarray_plot.py:1577, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1574 yvalnp = yval.to_numpy()
#    1576 # Pass the data as a masked ndarray too
# -> 1577 zval = darray.to_masked_array(copy=False)
#    1579 # Replace pd.Intervals if contained in xval or yval.
#    1580 xplt, xlab_extra = _resolve_intervals_2dplot(xvalnp, plotfunc.__name__)
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/core/dataarray.py:3892, in DataArray.to_masked_array(self, copy)
#    3878 def to_masked_array(self, copy: bool = True) -> np.ma.MaskedArray:
#    3879     """Convert this array into a numpy.ma.MaskedArray
#    3880
#    3881     Parameters
#    (...)
#    3890         Masked where invalid values (nan or inf) occur.
#    3891     """
# -> 3892     values = self.to_numpy()  # only compute lazy arrays once
#    3893     isnull = pd.isnull(values)
#    3894     return np.ma.MaskedArray(data=values, mask=isnull, copy=copy)
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/core/dataarray.py:788, in DataArray.to_numpy(self)
#     777 def to_numpy(self) -> np.ndarray:
#     778     """
#     779     Coerces wrapped data to numpy and returns a numpy.ndarray.
#     780
#    (...)
#     786     DataArray.data
#     787     """
# --> 788     return self.variable.to_numpy()
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/core/variable.py:1091, in Variable.to_numpy(self)
#    1089 """Coerces wrapped data to numpy and returns a numpy.ndarray"""
#    1090 # TODO an entrypoint so array libraries can choose coercion method?
# -> 1091 return to_numpy(self._data)
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/core/pycompat.py:111, in to_numpy(data)
#     108 from xarray.core.parallelcompat import get_chunked_array_type
#     110 if isinstance(data, ExplicitlyIndexed):
# --> 111     data = data.get_duck_array()
#     113 # TODO first attempt to call .to_numpy() once some libraries implement it
#     114 if hasattr(data, "chunks"):
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/core/indexing.py:613, in LazilyVectorizedIndexedArray.get_duck_array(self)
#     612 def get_duck_array(self):
# --> 613     array = self.array[self.key]
#     614     # self.array[self.key] is now a numpy array when
#     615     # self.array is a BackendArray subclass
#     616     # and self.key is BasicIndexer((slice(None, None, None),))
#     617     # so we need the explicit check for ExplicitlyIndexed
#     618     if isinstance(array, ExplicitlyIndexed):
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/rioxarray/_io.py:453, in RasterioArrayWrapper.__getitem__(self, key)
#     452 def __getitem__(self, key):
# --> 453     return indexing.explicit_indexing_adapter(
#     454         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     455     )
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/xarray/core/indexing.py:861, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     839 """Support explicit indexing by delegating to a raw indexing method.
#     840
#     841 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     858 Indexing result, in the form of a duck numpy-array.
#     859 """
#     860 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 861 result = raw_indexing_method(raw_key.tuple)
#     862 if numpy_indices.tuple:
#     863     # index the loaded np.ndarray
#     864     result = NumpyIndexingAdapter(result)[numpy_indices]
#
# File ~/opt/anaconda3/envs/mpc-env/lib/python3.11/site-packages/rioxarray/_io.py:430, in RasterioArrayWrapper._getitem(self, key)
#     426 with self.lock:
#     427     riods = _ensure_warped_vrt(
#     428         self.manager.acquire(needs_lock=False), self.vrt_params
#     429     )
# --> 430     out = riods.read(band_key, window=window, masked=self.masked)
#     431     if self._unsigned_dtype is not None:
#     432         out = out.astype(self._unsigned_dtype)
#
# File rasterio/_io.pyx:651, in rasterio._io.DatasetReaderBase.read()
#
# File rasterio/_io.pyx:978, in rasterio._io.DatasetReaderBase._read()
#
# RasterioIOError: Read or write failed. IReadBlock failed at X offset 7, Y offset 9: TIFFReadEncodedTile() failed.

# %% [markdown]
# The ‘cop-dem-glo-90’ collection contains the Copernicus DEM at 90m resolution (the data we previously used for the Grand Canyon).
#
# 1. Reuse the bbox for Santa Barbara to look for items in this collection.
# 2. Get the first item in the search and check its assets.
# 3. Check the item’s rendered preview asset by clicking on it’s URL.
# 4. Open the item’s data using rioxarray.

# %%
# 1 Reuse the bbox for Santa Barbara to look for items in this collection.
cop_collection = catalog.get_child('cop-dem-glo-90')
cop_collection

# Temporal range of interest
time_range = "2018-01-01/2023-01-01"

# NCEAS bounding box (as a GeoJSON)
bbox = {
    "type": "Polygon",
    "coordinates":[
        [
            [-119.70608227128903, 34.426300194372274],
            [-119.70608227128903, 34.42041139020533],
            [-119.6967885126002, 34.42041139020533],
            [-119.6967885126002, 34.426300194372274],
            [-119.70608227128903, 34.426300194372274]
        ]
    ],
}

# 2 Get the first item in the search and check its assets.
search = catalog.search(
    collections=['cop-dem-glo-90'],
    intersects=bbox,
    datetime=time_range)
search

# %%
# 3 Check the item’s rendered preview asset by clicking on it’s URL.

items1 = search.item_collection()
len(items1)
# Out:
# 1

# %%
# get first item in the catalog search
item = items1[0]
type(item)
# Out:
# pystac.item.Item

# %%
item.assets
# Out:
# {'data': <Asset href=https://elevationeuwest.blob.core.windows.net/copernicus-dem/COP90_hh/Copernicus_DSM_COG_30_N34_00_W120_00_DEM.tif?st=2023-11-26T21%3A41%3A58Z&se=2023-12-04T21%3A41%3A58Z&sp=rl&sv=2021-06-08&sr=c&skoid=c85c15d6-d1ae-42d4-af60-e2ca0f81359b&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2023-11-27T21%3A41%3A57Z&ske=2023-12-04T21%3A41%3A57Z&sks=b&skv=2021-06-08&sig=hTTxmvvVC2Ve0brdKnwXj4hEuSyMqengcMVzkExYwSU%3D>,
#  'tilejson': <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=cop-dem-glo-90&item=Copernicus_DSM_COG_30_N34_00_W120_00_DEM&assets=data&colormap_name=terrain&rescale=-1000%2C4000&format=png>,
#  'rendered_preview': <Asset href=https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=cop-dem-glo-90&item=Copernicus_DSM_COG_30_N34_00_W120_00_DEM&assets=data&colormap_name=terrain&rescale=-1000%2C4000&format=png>}

# %%
for key in item.assets.keys():
    print(key, '--', item.assets[key].title)
# Out:
# data -- N34_00_W120_00
# tilejson -- TileJSON with default rendering
# rendered_preview -- Rendered preview

# %%
Image(url=item.assets['rendered_preview'].href, width=500)
# Out:
# <img src="https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=cop-dem-glo-90&item=Copernicus_DSM_COG_30_N34_00_W120_00_DEM&assets=data&colormap_name=terrain&rescale=-1000%2C4000&format=png" width="500"/>

# %%
# 4 open the rasterio items.assets

dem = rioxr.open_rasterio(item.assets['data'].href)
dem
# Out:
# <xarray.DataArray (band: 1, y: 1200, x: 1200)>
# [1440000 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -120.0 -120.0 -120.0 ... -119.0 -119.0 -119.0
#   * y            (y) float64 35.0 35.0 35.0 35.0 35.0 ... 34.0 34.0 34.0 34.0
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Point
#     scale_factor:   1.0
#     add_offset:     0.0
